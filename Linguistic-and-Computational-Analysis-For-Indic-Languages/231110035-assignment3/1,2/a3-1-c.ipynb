# %% [markdown]
# # ChatGPT

# %% [markdown]
# ## (1) English to X

# %%
#English Dataset
with open('/kaggle/input/benchmarks689/benchmarks/wat2021-devtest/test.en', 'r') as file:
    en_dataset = file.readlines()
#print(en_dataset)
max_length_en = max(len(line.strip()) for line in en_dataset)

# %%
import random
num_lines = len(en_dataset)
indices = random.sample(range(num_lines), 1000)
indices = random.sample(range(len(indices)), 50)

# %%
with open('/kaggle/working/indices_c.txt', 'w', encoding='utf-8') as file:
        for index in indices:
            file.write(str(index)+'\n')

# %% [markdown]
# ### IF CRASHED

# %%
indices = []

# Read integers from the text file
with open('/kaggle/input/indices-c/indices_c.txt', 'r') as file:
    for line in file:
        indices.append(int(line.strip()))

# %%
sampled_en = []
for idx in indices:
    sampled_en.append(en_dataset[idx])

# %%
s_en = []
for sentence in sampled_en:
    words = sentence.split()
    s_en.append(words)

# %%
#sampled_en

# %%
predictions_en_mr = [
'त्याने जोडलं की त्यांचे प्रयत्न येथे भारतीय पासपोर्ट आपल्याला सर्वत्र समानाधिकाराने स्वीकृत केलं आहे.',
'प्रधानमंत्रीसह बोलताना, प्राध्यापकांनी आपल्या प्रेरणादायी कथा सांगितली, ज्यामध्ये त्यांच्या शाळांना शिक्षणाच्या आणि प्रतिष्ठेच्या केंद्रांमध्ये रूपांतरित करण्यात आले आहे.',
'दोन्ही पक्षांनी टीका घेतलं की, 2018 च्या जून महिन्यात क्विंग्डाओतील एससीओ मुख्यमंत्रीसोबत भारतीय गणराज्याच्या प्रधानमंत्री नरेंद्र मोदी यांची सहभाग योजनेत येण्याची सफळता अंगीकृत केली.',
'त्यांनी म्हणालं की, आजचा आयपीपीबीची सुरूवात हे या उद्दिष्टाच्या एक वाढ आहे.',
'प्रधानमंत्रीला दिलं की, स्वतंत्रता संघर्ष महात्मा गांधींच्या दृष्टिकोनातून सर्वसाधारण आंदोलन झालं.',
'माझे प्रिय देशवासियो, नमस्कार.',
'प्रधानमंत्री म्हणाले की, भारतातील आध्यात्मिक संस्थांनी सामाजिक सुधाराचे प्रसार केले आहे.',
'मला आशा आहे की ह्या नवीन पाठ्यक्रमाने ह्या व्यावसायात योग्यता घेतलेल्या नव्या आक्रमकांची आर्थिक क्षमता समूहित झाली जाईल.',
'चांगल्या ज्ञानाची मुख्य आधारे एक चांगल्या समाजाच्या अधिक मंजिलीची अनुसरण केली पाहिजे.',
'त्यांनी म्हणालं की ह्यामध्ये मध्यमला काढणारं आणि सरकारला मोठं बचत होईल.',

'90 टक्के पेक्षा जास्त अनुमोदने स्वयंसेवा मार्गावर ठेवली गेली आहेत.',
'आमच्या वाणिज्यिक आणि निवेश संबंधांमध्ये लवकरात लवक घटपट होत आहे.',
'तो सामाजिक आणि आर्थिक बदलाचा वास्तविक उद्दिष्ट प्राप्त करण्याचा प्रयत्न करण्याचा प्रयत्न करणे आवश्यक आहे.',
'मला आशा आहे की ज्याला बर्याचदा समयात सर्व स्तरावर अधिकारांचा जोर दिला जातो त्याला नागरिकांच्या कर्तव्यांच्या चर्चेसाठी एक द्रुष्टिकोन सोडवण्यात येतो, त्याच्याशी बर्याचदा चर्चा करण्याची आशा आहे.',
'प्रधानमंत्रींनी महात्मा गांधींच्या स्वच्छतेवरील निश्चयाबद्दल बोलले.',
'भारतीय बाजाराचा आकार आणि वाढ सर्वाधिक संभाव्य आहे.',
'पुनरावलोकनानंतर, प्रधानमंत्रीने राज्याला 500 कोटींची वित्ती सहाय्य घोषित केली.',
'अशा प्रकारे, ह्या प्राचीन इतिहासाच्या साहसी नागरिकांच्या, त्यांच्या विरासतीच्या आणि इतिहासाच्या कारणांच्या धैर्यासह आमच्या तरुण पिढ्यांची काळजी अद्याप आहे, हे स्पष्ट होतं.',
'"माझ्या भावना त्यांना नमूद केली जातात ज्याने जगदलपूर-भुवनेश्वर एक्सप्रेसच्या डिरेलमेंटमुळे त्यांच्या प्रियजनांना गमाविले आहेत.',
'एक वर्षाच्या कठीण कामानंतर, व्यक्तीच्या क्षमतेचा प्रदर्शन करण्याचा संधी असतो, म्हणून हे हर्ष आणि उत्साहाचे उत्सव असावं."',

'त्यांनी म्हणाले की, माणसांनी त्यांच्या गावांची, शहरे आणि क्षेत्रांची स्थानिक इतिहासाचे आणि पुराव्याचे महत्त्वाचे मार्ग घेणे आवश्यक आहे.',
'आज मला नवीन चार्टर्ड अकाऊंटन्सी पाठ्यक्रम सिलेबस सुरू करण्याचा संधी मिळाला.',
'त्याने ह्या विश्वकर्मा जयंतीला लहानांचा अभिनंदन केला, आणि म्हणाले की विविध कौशल्ये शिकणे महत्त्वाचं आहे.',
'त्यांनी साखरपुढा आयोजित करण्याचे आणि जिल्ह्यांमध्ये मॉक पार्लियमेंट्स आयोजित करण्याचे आवाहन केले होते, हे त्यांनी दिसेल की, डिसेंबर २०१७ मध्ये मन की बातमध्ये.',
'"महात्मा फुले यांना त्यांच्या जयंतीविषयी श्रद्धांजली.',
'त्यांनी श्री इनामदारांच्या "बिना संस्कार, नहीं सहकार" या मंत्राची पुनरावृत्ती केली.',
'दोन्ही पक्षांनी प्राधान्यानुसार आईएनएसटीसी मंत्रिमंडळ आणि समन्वय सभेचा आयोजन करण्याच्या प्रयत्नांसाठी सहमत झाले.',
'तुम्हाला सर्व्हच कल्पना आहे की शेतराणी निर्माणासाठी सरकारने किती प्रशासकीय आणि आर्थिक कदम घेणे आवश्यक आहेत.',
'बिम्स्टेक ह्या क्षेत्रीय सहकार्याचा प्राकृतिक मंच आहे.',
'राष्ट्रपती शी आणि मी द्विपक्षीय आणि वैश्विक महत्त्वाच्या विविध विषयांवर विचारांचा आदान-प्रदान करू.',

'या दिवशी उद्घाटन केलेल्या प्रकल्पांची किंमत प्रधानमंत्रींनी म्हणाले की, आज उद्घाटन केलेल्या किंमतीची, किंवा ज्यांचे आज आधारशिला ठेवले गेले, त्याची कुल किंमत १४,००० कोटीपर्यंत आहे.',
'त्यांनी म्हणाले की, सध्याच्या सुविधेच्या प्रवेशानंतरही पोस्टमनवर विश्वास बाकी आहे.',
'दोन्ही पक्षांनी ही थीमवरील बहुमुखी चर्चेची प्रामुख्याने जाहीर केली, पूर्व एशिया सम्मेलन आणि इतर क्षेत्रीय संघांमध्ये आणि इतर क्षेत्रीय मंचांतर्गत.',
'दुसरं, जन औषधी केंद्रांची एक सिरीस देशभर उत्तीर्ण केली गेली.',
'त्याने आयोध्या ते रामेश्वरमध्ये एक नवीन एक्स्प्रेस ट्रेनचा फ्लॅग-ऑफ करेल (व्हिडिओ काँफ्रेंसिंग मार्फत).',
'माझ्या विचारांचं आणि प्रार्थना आत्तापर्यंत तमिळनाडूच्या लोकांशी आहेत.',
'आमच्या कुटुंबातील मुलांकडून खेळाच्या आग्रहांची योग्यता असल्यास, त्यांना संधी द्यायला पाहिजे.',
'आमच्या देशात कौशल्याची कमतरता नाही.',
'सरकार प्रत्येक देशाच्या प्रत्येक नागरिकाच्या २०२२ मध्ये एक घर असल्याचं ध्यास साधत आहे.',
'प्रधान विद्यार्थ्यांना त्यांच्या वैज्ञानिक कौशल्यांसाठी सराहलं आणि त्यांना अधिक अशी उत्पत्तींचा आविष्कार करायला प्रोत्साहित केलं.',

'या सुविधेच्या देशातील सर्वात मोठं अंतर्भूमि भंडार आहे.',
'त्याचे अवसान दुःखद आहे.',
'आता ते आर्थिक सेवा प्रदान करण्यासाठी स्मार्टफोन्स आणि डिजिटल डिव्हायसेसच्या सानिध्याने सक्षम होणार आहेत.',
'मी राष्ट्रपती सिरिसेना, प्रधानमंत्री विक्रेमसिंग्ह आणि इतर प्रमुख गौरवमय व्यक्तींसोबत मिळणार आहे.',
'आता, महाद्वीप स्वयंच्या वैश्विक आर्थिक क्रियाकलापाच्या केंद्रात आहे.',
'द्वारे विनिमय केलं.',
'प्रधानमंत्रीने म्हणाले की, भारतीय मनोरंजन उद्योगाला जगातील अत्यंत पॉपुलरिटी मिळते.',
'मित्रांनो, ह्या जगातील ह्या प्रकारची प्रथम कॉन्फरेन्स आहे.',
'इटानगरपासून, पीएम गुवाहाटीला परत येणार आहे.',
'आम्ही सौर ऊर्जा संजालातील सहकारी प्रयत्न करीत आहोत, अंतरराष्ट्रीय सौर गटाच्या रूपात त्याचे मुख्यस्थान घेण्यासाठी.'
] 

#LINK: https://chat.openai.com/share/96b3bffa-2d89-47b4-9e91-2ee3c6feeada

# %%
#Marathi Dataset
with open('/kaggle/input/benchmarks689/benchmarks/wat2021-devtest/test.mr', 'r') as file:
    mr_dataset = file.readlines()
#print(mr_dataset)
max_length_mr = max(len(line.strip()) for line in mr_dataset)

# %%
sampled_mr = []
for idx in indices:
    sampled_mr.append(mr_dataset[idx])

# %%
s_mr = []
for sentence in sampled_mr:
    words = sentence.split()
    s_mr.append(words)

# %%
# for i in range(len(predictions_mr)):
#     print(i," ",predictions_mr[i])

# %%
# for i in range(len(sampled_mr)):
#     print(i," ",sampled_mr[i])

# %%
with open('/kaggle/working/predictions_en_mr.txt', 'w', encoding='utf-8') as file:
        for sentence in predictions_en_mr:
            file.write(sentence.strip() + '\n')

# %% [markdown]
# ## (2) X to English

# %%
sampled_mr[40:50]
# Out:
# ['देशातली भूमीगत साठ्याची ही सर्वात मोठी सुविधा आहे.\n',
#  'त्यांचे निधन दु:खदायी आहे.\n',
#  'या ग्रामीण डाकसेवकांना स्मार्ट फोन आणि डिजिटल साधने देऊन त्यांना वित्तीय सेवा पुरवणारे सहाय्यक बनवले जाईल.\n',
#  'मी राष्ट्रपती सिरीसेना, पंतप्रधान विक्रमसिंघे आणि इतर मुख्य मान्यवरांची देखील भेट घेणार आहे.\n',
#  'आता हा उपखंड स्वतःला जागतिक आर्थिक घडामोडींच्या केंद्रस्थानी मानतो.\n',
#  'स्वाक्षरी करणारे अधिकारी/राजदूत\n',
#  'भारतीय चित्रपट जगभरात अत्यंत लोकप्रिय आहेत असे पंतप्रधान यावेळी म्हणाले.\n',
#  'मित्रहो, जगाच्या या भागात होत असलेली अशा प्रकारची ही पहिलीच परिषद आहे.\n',
#  'इटानगरहून पंतप्रधान गुवाहाटीला परत येतील.\n',
#  'आम्ही आंतरराष्ट्रीय सौर आघाडी स्वरूपात सौरऊर्जेला मुख्य प्रवाहात आणण्याचा सामूहिक प्रयत्न करीत आहोत.\n']

# %%
predictions_mr_en = [
"They said that because of their efforts, respect is shown everywhere for the Indian passport.",
"Teachers who won awards for their efforts to establish education and excellence centers in their schools shared inspirational stories with the Prime Minister at this time.",
"In the meeting of the SCO held in Qingdao in June 2018, Indian Prime Minister Narendra Modi's participation as a full-fledged member of this organization demonstrates India's successful participation in the organization's work, as stated by both countries.",
"They further stated that the Indian Post Payment Bank is the next step in this sector.",
"Thanks to the efforts made with the foresight of Mahatma Gandhi, the struggle for independence became a people's movement.",
"My dear countrymen, greetings.",
"Spiritual organizations have worked as centers for the spread of social reforms in India.",
"I am confident that with the introduction of new training programs, this business will further strengthen the financial skills of these new people.",
"By ensuring a strong foundation of good knowledge, a broad framework for building a good society has been established.",
"They indicated that this would lead to the elimination of brokers and savings for the government.",
    
"Approval for more than 90% of FDIs has been granted through automatic route.",
"Business and trade relations in your area are experiencing significant growth.",
"Efforts need to be made to achieve the real goal of bringing about social and economic change through this turmoil.",
"I hope that at every level, as much importance is given to duties as it is to rights.",
"The Prime Minister emphasized the commitment to cleanliness made by Mahatma Gandhi.",
"The size and growth of the Indian marketplaces are highly robust.",
"Following this summit, Prime Minister Narendra Modi announced an economic aid package of 500 crore rupees for Kerala.",
"The popularity of organizing all these festivals during this festive season indicates that the youth of today are also very attracted to our ancient traditions and the history of brave heroes.",
"The Prime Minister said, 'I share in the grief of the families who have lost their loved ones in the tragic accident of the Jagdalpur-Bhubaneswar Express train derailment.'",
"The enthusiasm to show the results of the hard work done throughout the year is now evident in this season.",
    
"They expressed the expectation of making efforts to learn the history and archaeology of their cities, villages, and states.",
"Today, I have the opportunity to start the new Chartered Accountancy Course Curriculum.",
"Students from Narur Khedya Primary School welcomed the Prime Minister with enthusiasm upon his arrival.",
"In December 2017, they remembered their announcement to organize the representation of MPs in all districts of the country during the 'Mann Ki Baat' program.",
"Homage to Mahatma Phule on his birth anniversary.",
"They reiterated the mantra of 'No cooperation without education'.",
"Both sides agreed to organize ministerial-level and cooperative meetings for the NSECS.",
"You may be aware of how many administrative and financial hurdles the government faces in constructing highways.",
"This is a natural platform for regional cooperation.",
"Xi Jinping and I will discuss various bilateral and global issues.",
    
"Speaking at this moment, the Prime Minister said that the total value of projects inaugurated, dedicated, and initiated for implementation exceeds 14,000 crore rupees.",
"Even after the advent of new technology, confidence in the postal department remains intact.",
"The importance of initiating multilateral dialogues on this subject at the forum of the East Asia Summit and other regional platforms was emphasized by both countries.",
"Another development is the establishment of ownership of public health centers throughout the country.",
"From Ayodhya to Rameswaram, this new train will showcase the green lantern.",
"In this moment of sorrow, my feelings are with the people of Tamil Nadu.",
"If there is joy in playing games with your family, then they should be given the opportunity.",
"There is no shortage of talented athletes in the country.",
"By 2022, there should be a home for everyone in the country, and the government is actively working towards this goal.",
"The Prime Minister encouraged students to showcase their scientific skills and promised to support them in advancing further.",
    
"This is the biggest facility in the country for land-related records.",
"Their demise is saddening.",
"These rural postal workers will be appointed as assistants to provide financial services by providing them with smartphones and digital resources.",
"I will also meet President Sirisena, Prime Minister Vikram Singh, and other dignitaries.",
"Now this region considers itself at the center of global economic developments.",
"Diplomats/ambassadors who will sign.",
"The Prime Minister mentioned that Indian films are extremely popular worldwide.",
"Friends, this is the first council of its kind in this region of the world.",
"The Prime Minister will return to Guwahati from Itanagar.",
"We are making collective efforts to bring solar energy into the mainstream as part of international solar leadership."
]

#LINK : https://chat.openai.com/share/2b264c45-66cc-434a-984b-1ba8b994d513

# %%
len(predictions_mr_en)
# Out:
# 50

# %%
with open('/kaggle/working/predictions_mr_en.txt', 'w', encoding='utf-8') as file:
        for sentence in predictions_mr_en:
            file.write(sentence.strip() + '\n')

# %% [markdown]
# ## (3) One Indian language (other than X), say Y, to X

# %%
#Hindi Dataset
with open('/kaggle/input/benchmarks689/benchmarks/wat2021-devtest/test.hi', 'r') as file:
    hi_dataset = file.readlines()
#print(hi_dataset)
max_length_hi = max(len(line.strip()) for line in hi_dataset)

# %%
sampled_hi = []
for idx in indices:
    sampled_hi.append(hi_dataset[idx])

# %%
s_hi = []
for sentence in sampled_hi:
    words = sentence.split()
    s_hi.append(words)

# %%
sampled_hi[40:50]
# Out:
# ['यह देश की सबसे बड़ी भूमिगत भंडारण सुविधा है।\n',
#  'श्री हॉकिंग का जाना दुखद है।\n',
#  'अब लोगों को वित्तीय सेवाएं सुलभ कराने के उद्देश्\u200dय से उन्हें स्मार्टफोन और डिजिटल उपकरणों के माध्\u200dयम से सशक्त बनाया जाएगा।\n',
#  'मैं राष्ट्रपति सिरीसेना, प्रधानमंत्री विक्रमसिंघे और अन्य प्रतिष्ठित गणमान्य लोगों के साथ मुलाकात करूंगा।\n',
#  'अब यह महाद्वीप खुद वैश्विक आर्थिक गतिविधियों का केन्\u200dद्र बन गया है।\n',
#  'आदान-प्रदान इनके द्वारा\n',
#  'प्रधानमंत्री ने कहा की भारतीय मनोरंजन उद्योग दुनिया भऱ में लोकप्रिय है।\n',
#  'साथियों, धरती के इस हिस्से में ये अपनी तरह की पहली कॉन्फ्रेंस है।\n',
#  'ईटानगर से प्रधानमंत्री गुवाहाटी वापस आएंगे।\n',
#  'हम एक अंतर्राष्\u200dट्रीय सौर गठबंधन के रूप में सौर ऊर्जा को मुख्\u200dय धारा में लाने के लिए भी आपसी सहयोग के साथ अथक प्रयास कर रहे हैं।\n']

# %%
predictions_hi_mr = [

'त्यांनी सांगितलं कि प्रवासी भारतीयांच्या प्रयत्नांमुळे सर्वत्र भारतीय पासपोर्टवर सम्मान दिला गेला आहे।'
,
'प्रधानमंत्रीसह चर्चा केल्यास बहुप्रसिद्ध विजेत्यांनी आपल्या शाळांना शिक्षण आणि उत्कृष्टता केंद्रात रूपांतरित करण्याच्या संदर्भातील प्रेरणादायक कथांनी दाखविलं।'
,
'दोन्ही पक्षांनी या घटनेची नोंद केली की, 2018 मध्ये क्विंगडाओमध्ये आयोजित झालेल्या एससीओ राष्ट्राध्यक्ष परिषदेत भारताचे प्रधानमंत्री श्री. नरेंद्र मोदी यांचे संघटनेत एक पूर्णकाळ सदस्य म्हणून भारताचं सदस्यत्व सापडलं असून भारताचं कामकाज या संघटनेत सफलतेने सहभाग केलं ते दर्शवतं।'
,
'त्यांनी सांगितलं कि आज "आईपीपीबी" चे उद्दीश्य पूर्ण करण्यासाठी अधिक महत्त्वाचं एक कदम आहे।'
,
'प्रधानमंत्रीने सांगितलं कि स्वतंत्रता संग्राम महात्मा गांधींच्या प्रयत्नांमुळे जन आंदोलन आला आहे।'
,
'माझे प्रिय देशवासी, नमस्कार।'
,
'प्रधानमंत्रीने सांगितलं कि भारतात आध्यात्मिक संस्थांनी सामाजिक सुधाराच्या केंद्रावर राहावे आहे।'
,
'मला आशा आहे कि नवीन कोर्स या पेशेवरीत येणार्\u200dया लोकांच्या आर्थिक कौशल्यांना आणि मजबूत करेल।'
,
'चांगले ज्ञानाच्या आधारावरच एक चांगला समाज तयार केले पाहिजे।'
,
'त्यांनी सांगितलं कि हे सांगा बंद करेल आणि त्यामुळे सरकारला बचत होईल।'
,
'90 प्रतिशतपेक्षा अधिक मंजूरी स्वत: रूटवरून मिळतात।'
,
'आमच्या आणि निवेशाच्या संबंधांतील प्रगाढ होण्याचा प्रयत्न चालू आहे।'
,
'बरंच लोकांनी हे सामाजिक आणि आर्थिक बदल करण्याचे लक्ष्य घेतले पाहिजे.'
,
'मला आशा आहे की प्रत्येक स्तरावर, प्रत्येक वेळी, अधिकारांवर किती शक्ती दिली जाते त्याप्रमाणे कर्तव्यांवरही त्याची शक्ती दिली जाईल.'
,
'प्रधानमंत्रीने स्वच्छतेवर महात्मा गांधींचे संकल्प चर्चा केली.'
,
'भारतीय बाजारात अशी अपार संभावना आहेत कि.'
,
'समीक्षा बैठकानंतर प्रधानमंत्रीने राज्याला ५०० कोटींची आर्थिक सहाय्य केल्याची घोषणा केली.'
,
'हे दर्शवतं कि आमचे प्राचीन विरासत आणि इतिहासातील आमच्या वीर नायकांवरी आजही आमच्या युवा पिढ्यात craze आहे.'
,
'जगदलपुर-भुवनेश्वर एक्सप्रेस पथावरून उतरण्याच्या कारणी जगाच्या जीवनात आपल्या प्रियजनांची अशी नुकसाने झाल्यानंतर त्यांच्याशी माझ्या संवेदना आहेत।'
,
'वर्षभर केलेल्या मेहनतीचा आता परिणाम दाखवण्याचा संवेदना हा उत्साहात्मक आणि उत्कृष्ट उत्सव असावा.'
,
'त्यांनी सांगितलं कि लोकांना स्थानिक इतिहास आणि त्यांच्या शहरां आणि क्षेत्रांच्या पुरातत्वाबद्दल माहिती मिळवावी चाहिए.'
,
'आज मला नवीन Chartered Accountancy Course Curriculum सुरू करण्याचा अवसर मिळाला.'
,
'प्रधानमंत्रीने विश्वकर्मा जयंतीच्या अवसराला बालकांना शुभेच्छा दिली आणि सांगितलं कि विविध प्रकारच्या कौशले शिकण्याची महत्त्वाची आहे.'
,
'त्यांनी २०१७ मध्ये मन की बातमध्ये त्यांचं भाषण आणलं होतं ज्यात त्यांनी जिल्ह्यांमध्ये कृत्रिम संसदांचे आयोजन करण्याची विनंती केली होती.'
,
'प्रधानमंत्रीने म्हणाले "जन्मजयंती दिवसी महात्मा फुले यांना श्रद्धांजली."'
,
'त्यांनी श्री इनामदारच्या मंत्र "बिना संस्कार, नहीं सहकार" वापरलं.'
,
'दोन्ही पक्षांनी प्राथमिकता आधारीत आयएनएसटीसी मंत्रिमंडळीय आणि समन्वय बैठक बुलवून सहमती व्यक्त केली.'
,
'तुम्हाला केवळ माहित आहे की Highways निर्माणात सरकारला किती प्रशासनिक आणि आर्थिक कदम उचलण्याची आवश्यकता असते.'
,
'बिम्सटेक क्षेत्रिय सहकार्यासाठी एक स्वाभाविक मंच आहे.'
,
'राष्ट्रपती शी आणि मी द्विपक्षीय आणि वैश्विक महत्त्वाच्या अनेक मुद्दांवर विचार करण्याचा मार्ग घेणार आहोत.'
,
'त्यांनी संबोधनात सांगितलं कि आज केलेल्या प्रकल्पांचं उद्घाटन किंवा त्यांची मुळभूमी ठेवण्यात आलेल्या वस्तूंचा कुल मूल्य १४ हजार कोटीपेक्षा जास्त आहे.'
,
'त्यांनी सांगितलं कि आधुनिक तंत्रज्ञानाने आहेत की, डाकघराच्या विश्वासाने आता पण होतं.'
,
'दोन्ही पक्षांनी पूर्वी आशियातील शिखर सम्मेलनांच्या आणि इतर क्षेत्रीय फोरमांच्या विचारांत बसून ह्या विषयावर बहुपक्षीय संवादांच्या महत्त्वाची प्राथमिकता दिली.'
,
'दुसरं, पूर्ण देशात जनऔषधी केंद्रांचं एक सरण आरंभ केलं.'
,
'ते व्हिडिओ कॉन्फ्रेन्सिंगद्वारे अयोध्या पासून रामेश्वरमकडे एक नवीन एक्सप्रेस ट्रेनची भी घोषणा करेल.'
,
'दुःखातील या क्षणात माझी संवेदना आणि प्रार्थना तमिळनाडूच्या लोकांसोबत आहेत.'
,
'जर आमच्या कुटुंबातील मुलांना खेळाची आवड असेल तर, त्यांना त्यांच्यासाठी अवसर द्यावं.'
,
'देशात प्रतिभांची कमी नाही.'
,
'२०२२ पर्यंत देशातील प्रत्येकाच्या प्रमाणात त्यांचं घर असणे, हे लक्ष्य सरकारने पण काम करीत आहे.'
,
'प्रधानमंत्रीने शाळेतील विद्यार्थ्यांच्या वैज्ञानिक क्षमतांवर सराहना केली आणि त्यांना त्यांच्यासाठी अधिक आणि नवीन आविष्कारांचे प्रोत्साहन दिले.'
,
'हे देशातील सर्वात मोठं भूमिगत भंडारण सुविधा आहे.'
,
'श्री हॉकिंगचं निघालं, हे दु:खद आहे.'
,
'आता लोकांना वित्तीय सेवांना सुलभ करण्याच्या उद्देशाने त्यांना स्मार्टफोन आणि डिजिटल उपकरणांच्या माध्यमातून सशक्त केलं जाईल.'
,
'मी राष्ट्रपती सिरीसेन, प्रधानमंत्री विक्रमसिंघ आणि इतर प्रतिष्ठित लोकांसोबत मिळवणार आहे.'
,
'आता हा महाद्वीप आपल्या स्वत: वैश्विक आर्थिक क्रियाकलापांचा केंद्र बनला आहे.'
,
'या द्वारे आदान-प्रदान होईल.'
,
'प्रधानमंत्रीने म्हणाले की भारतीय मनोरंजन उद्योग जगात लोकप्रिय आहे.'
,
'साथियों, पृथ्वीच्या ह्या भागात या अपनी पहिली कॉन्फ्रेंस आहे.'
,
'ईटानगरपासून प्रधानमंत्री गुवाहाटीत परत येतील.'
,
'आम्ही एक आंतरराष्ट्रीय सौर संघाच्या रूपात सौर ऊर्जेला मुख्यस्थानात आणण्यासाठी सहयोगाच्या प्रयत्नांमध्ये आहोत.'
]

#LINK: https://chat.openai.com/share/b6da7f36-34e9-4359-98e4-54113c787576

# %%
len(predictions_hi_mr)
# Out:
# 50

# %%
with open('/kaggle/working/predictions_hi_mr.txt', 'w', encoding='utf-8') as file:
        for sentence in predictions_hi_mr:
            file.write(sentence.strip() + '\n')

# %% [markdown]
# ## (4) X to Y

# %%
sampled_mr[40:50]
# Out:
# ['देशातली भूमीगत साठ्याची ही सर्वात मोठी सुविधा आहे.\n',
#  'त्यांचे निधन दु:खदायी आहे.\n',
#  'या ग्रामीण डाकसेवकांना स्मार्ट फोन आणि डिजिटल साधने देऊन त्यांना वित्तीय सेवा पुरवणारे सहाय्यक बनवले जाईल.\n',
#  'मी राष्ट्रपती सिरीसेना, पंतप्रधान विक्रमसिंघे आणि इतर मुख्य मान्यवरांची देखील भेट घेणार आहे.\n',
#  'आता हा उपखंड स्वतःला जागतिक आर्थिक घडामोडींच्या केंद्रस्थानी मानतो.\n',
#  'स्वाक्षरी करणारे अधिकारी/राजदूत\n',
#  'भारतीय चित्रपट जगभरात अत्यंत लोकप्रिय आहेत असे पंतप्रधान यावेळी म्हणाले.\n',
#  'मित्रहो, जगाच्या या भागात होत असलेली अशा प्रकारची ही पहिलीच परिषद आहे.\n',
#  'इटानगरहून पंतप्रधान गुवाहाटीला परत येतील.\n',
#  'आम्ही आंतरराष्ट्रीय सौर आघाडी स्वरूपात सौरऊर्जेला मुख्य प्रवाहात आणण्याचा सामूहिक प्रयत्न करीत आहोत.\n']

# %%
predictions_mr_hi = [
'उनके प्रयासों के कारण भारतीय पासपोर्ट का हर जगह सम्मान किया जाता है, ऐसा कहा गया।',
'हमारे स्कूल के शिक्षा और उत्कृष्टता के केंद्र के निर्माण के लिए की गई प्रयासों की प्रेरणादायक कहानियाँ, पुरस्कार विजेता शिक्षकों ने इस समय प्रधानमंत्री को बताया।',
'2018 में जून के महीने में क्विंगडाओ में आयोजित एससीओ राष्ट्रपति सम्मेलन में भारतीय प्रधानमंत्री नरेंद्र मोदी ने एक पूर्णकालिक सदस्य के रूप में इस संगठन के कार्य में भारत की सफलता का सहभाग दिखाया।',
'उन्होंने आगे कहा कि, भारतीय पोस्ट पेमेंट बैंक इस क्षेत्र में अगला कदम है।',
'महात्मा गांधी जी की दूरदृष्टि के माध्यम से की गई प्रयासों के कारण, स्वतंत्रता की लड़ाई लोगों के अनुभव का हिस्सा बन गई।',
'मेरे प्यारे देशवासियों, नमस्कार।',
'सामाजिक सुधार केन्द्र के रूप में भारत में आध्यात्मिक संस्थाएँ काम की हैं।',
'मुझे यकीन है कि नए पाठ्यक्रम, इस व्यवसाय में आने वाले नए लोगों के वित्तीय कौशल और और भी मजबूत करेंगे।',
'अच्छे ज्ञान की मजबूत आधारशिला रखकर, अच्छे समाज का एक व्यापक रूप तैयार किया जाना चाहिए।',
'इससे दलालों की उच्चाटन होगी और सरकार की बचत होगी, यह उन्होंने कहा।',

'90% से अधिक आवेदनों को स्वचालित तरीके से अनुमोदन दिया गया है।',
'आपके व्यापार और निवेश संबंध अधिक वृद्धि कर रहे हैं।',
'इस उलटा प्रभाव के कारण सामाजिक और आर्थिक परिवर्तनों को बढ़ावा देने के वास्तविक उद्देश्य के लिए प्रयास किया जाना चाहिए।',
'मुझे आशा है कि हर स्तर पर, जितना महत्व अधिकारियों को दिया जाता है उतना ही महत्व कर्तव्यों को भी दिया जाना चाहिए।',
'महात्मा गांधी जी की स्वच्छता के लिए उन्होंने प्रतिबद्धता व्यक्त की।',
'भारतीय बाजार का आकार और विकास बहुत ही सामर्थ्यशाली है।',
'इस आदान-प्रदान के बाद, प्रधानमंत्री नरेंद्र मोदी ने केरल को 500 करोड़ रुपये की आर्थिक सहायता घोषित की।',
'इन आयोजनों की लोकप्रियता में इस सारे उत्सवों का वास्तविक उद्देश्य है कि हमें यह दिखाएं कि हमारी प्राचीन परंपराओं और इतिहास के वीर नेताओं के प्रति आज की युवा पीढ़ी भी कितना आकर्षित है।',
'प्रधानमंत्री ने कहा, "जगदालपुर-भुवनेश्वर एक्सप्रेस ट्रेन के डिब्बे दुर्घटना में फंस गए लोगों के परिजनों के दुःख में मैं सहभागी हूं।"',
'साल भर की मेहनत के बाद इसे दिखाने का मौका अब मिला है और इस काल में हमें इसके लिए उत्साहित होना चाहिए।',

'लोगों ने अपने शहर, गाँव और प्रांत के इतिहास और पुरातत्व परंपरा को जानने की कोशिश करने की उम्मीद व्यक्त की है।',
'नए सनदी लेखापालन अभ्यासक्रम (Chartered Accountancy Course Curriculum) की शुरुआत करने का मुझे आज मौका मिला है।',
'नारूर खेड्यातील प्राथमिक शालाओं के छात्रों ने प्रधानमंत्री का आगमन स्वागत किया।',
'दिसंबर 2017 में "मन की बात" कार्यक्रम के दौरान देश के सभी जिलों में सांसदों के अभिरुचि अनुसार आयोजन करने की उनकी अधिसूचना को वे इस समय याद कराई।',
'"महात्मा फुले जयंती" के अवसर पर उन्हें श्रद्धांजलि अर्पित की गई।',
'"संस्कार के बिना, सहयोग नहीं" इस सज्जन के मंत्र को उन्होंने दोहराया।',
'आयएनएसटीसी मंत्री स्तरीय और सहकार्य बैठक का आयोजन करने के बारे में दोनों पक्षों ने सहमति जताई।',
'महामार्ग निर्माण के लिए सरकार को कितनी प्रशासकीय और वित्तीय पारीश्रमिकता की आवश्यकता है, आपको यह जानना चाहिए।',
'यह प्रादेशिक सहकार्य के दृष्टिकोण से प्राकृतिक मंच है।',
'द्विपक्षीय और वैश्विक महत्वपूर्ण विभिन्न मुद्दों पर जिनपिंग और मैं चर्चा करने जा रहे हैं।',
    
'इस वक्त, प्रधानमंत्री ने कहा कि, आज उद्घाटन, राष्ट्रार्पण और प्रोजेक्ट्स की अंतिम लागत 14 हजार करोड़ से अधिक है।',
'नए तकनीकी विज्ञान के आगमन के बाद भी पोस्टल सेवा पर विश्वास बना रहने का मौका है।',
'पूर्वी एशिया शिक्षा परिषद और अन्य क्षेत्रीय मंचों ने इस विषय पर बहुपक्षीय बहस शुरू करने के महत्व को उजागर किया।',
'दूसरा, पूरे देश में जनस्वास्थ्य केंद्रों की स्थापना हुई है।',
'अयोध्या से रामेश्वर तक इस नई ट्रेन को हिरवा कंदिल दिखाया जाएगा।',
'इस दुख के क्षण में मेरी भावनाएं तमिलनाडु की जनता के साथ हैं।',
'अगर आपके परिवार के बच्चों को खेलने का मन है, तो उन्हें इसका मौका देना चाहिए।',
'देश में प्रतिभाशाली खिलाड़ियों की कमी नहीं है।',
'2022 तक देशभर में हर किसी को अपना घर हो, इसके लिए सरकार प्रयासरत है।',
'विज्ञान कुशलताओं के आश्चर्य करते हुए उन्हें ऐसे ही अग्रेजित करने के लिए प्रोत्साहन प्रधानमंत्री ने दिया।',

'देश के लिए भूमिगत सेवा यह सबसे बड़ी सुविधा है।',
'उनका निधन दुखदायी है।',
'इन ग्रामीण डाक सेवकों को स्मार्ट फोन और डिजिटल साधनों की मदद से वित्तीय सेवाएं प्रदान करने के लिए सहायक बनाया जाएगा।',
'मैं राष्ट्रपति सिरीसेना, प्रधानमंत्री विक्रमसिंघ और अन्य मुख्य व्यक्तियों से मिलूंगा।',
'अब यह उप-जिला ग्लोबल आर्थिक घडामोडी का केंद्र होगा।',
'हस्ताक्षर करने वाले अधिकारी/राजदूत',
'भारतीय फिल्मों को विश्व में बहुत पसंद किया जाता है, यह प्रधानमंत्री ने कहा।',
'मित्रों, इस जगह में जो भी है, वह पहली बार की इस परिषद है।',
'इटानगर से प्रधानमंत्री गुवाहाटी लौटेंगे।',
'हम अंतरराष्ट्रीय सौर योजना के रूप में सौर ऊर्जा को मुख्य प्रवाह में लाने के लिए समूहिक प्रयास कर रहे हैं।'

]

#LINK: https://chat.openai.com/share/4456819a-9c8f-41d3-8493-7c0bbcfc04e4

# %%
len(predictions_mr_hi)
# Out:
# 50

# %%
with open('/kaggle/working/predictions_mr_hi.txt', 'w', encoding='utf-8') as file:
        for sentence in predictions_mr_hi:
            file.write(sentence.strip() + '\n')

# %% [markdown]
# ## Q2 : BLEU and ROUGE scores(different variants)

# %%
# !pip install evaluate
# !pip install rouge
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.0 MB/s eta 0:00:00
# ...

# %%
import evaluate
from nltk.translate.bleu_score import corpus_bleu, sentence_bleu
import nltk

predictions = [predictions_en_mr, predictions_mr_en, predictions_hi_mr, predictions_mr_hi]
references = [s_mr,s_en,s_mr,s_hi]    #[sampled_mr, sampled_en, sampled_mr, sampled_hi]
tgt_lang = ['mar_Deva', 'eng_Latn', 'mar_Deva', 'hin_Deva']

bleu = evaluate.load("bleu")

for i in range(len(predictions)):
    print("Results for", tgt_lang[i], "are:\n")
    
    corpus_score = corpus_bleu(references[i], predictions[i])
    print("Corpus BLEU Score:", corpus_score, '\n')
    
    SentenceBleu = []
    
    for j in range(len(predictions[i])):
        hypothesis_tokens = nltk.word_tokenize(predictions[i][j].lower())
        reference_tokens = [nltk.word_tokenize(ref.lower()) for ref in references[i][j]]
        sentence_score = sentence_bleu(reference_tokens, hypothesis_tokens)
        SentenceBleu.append(sentence_score)
    
    AvgSentenceBleu = sum(SentenceBleu)/len(SentenceBleu)
    print("Sentence BLEU Score:", AvgSentenceBleu, '\n')

    results_bleu = bleu.compute(predictions=predictions[i], references=references[i])

    print(results_bleu,'\n')
# Out:
# 2024-04-17 12:57:19.129907: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-17 12:57:19.130032: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-17 12:57:19.274052: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
# Results for mar_Deva are:
#
# Corpus BLEU Score: 0.23427609593434068
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# ...

# %%
references = [sampled_mr, sampled_en, sampled_mr, sampled_hi]         
from rouge import Rouge
rouge = Rouge()

for i in range(len(predictions)):
    print("ROUGE Score for", tgt_lang[i], "are:")
    scores = rouge.get_scores(predictions[i], references[i],avg=True)
    print(scores,'\n')
# Out:
# ROUGE Score for mar_Deva are:
# {'rouge-1': {'r': 0.21628396086484322, 'p': 0.2443572522248993, 'f': 0.22801300891212162}, 'rouge-2': {'r': 0.046876658429290015, 'p': 0.05280485882404042, 'f': 0.049350609460652076}, 'rouge-l': {'r': 0.19288919468331234, 'p': 0.21864592760180993, 'f': 0.20358756921280252}}
#
# ROUGE Score for eng_Latn are:
# {'rouge-1': {'r': 0.4311687200039778, 'p': 0.4562961800642239, 'f': 0.439112857376589}, 'rouge-2': {'r': 0.22453322961008715, 'p': 0.23881805734044928, 'f': 0.22867506315234415}, 'rouge-l': {'r': 0.3793591510077416, 'p': 0.4031315555679106, 'f': 0.3873836222880518}}
#
# ROUGE Score for mar_Deva are:
# {'rouge-1': {'r': 0.217405647185059, 'p': 0.2452352731547779, 'f': 0.22832523186532472}, 'rouge-2': {'r': 0.04858846382375795, 'p': 0.05525153235137756, 'f': 0.05125893020997726}, 'rouge-l': {'r': 0.19489190847279086, 'p': 0.21918291907610793, 'f': 0.20441854797354947}}
#
# ROUGE Score for hin_Deva are:
# ...

# %%
# !zip -r file.zip /kaggle/working

# %%
# !ls
# Out:
# file.zip       predictions_en_mr.txt  predictions_mr_en.txt  state.db
# indices_c.txt  predictions_hi_mr.txt  predictions_mr_hi.txt

# %%
from IPython.display import FileLink
FileLink(r'file.zip')
# Out:
# /kaggle/working/file.zip
